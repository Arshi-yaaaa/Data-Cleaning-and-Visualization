# %% [markdown]
# <a href="https://colab.research.google.com/github/Arshi-yaaaa/Data-Cleaning-and-Visualization/blob/main/Data_cleaning_and_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55dfafb1-29f5-4ed5-b367-6e78add3a48a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55dfafb1-29f5-4ed5-b367-6e78add3a48a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('dataset')

print("Files extracted successfully!")
# Out:
# Files extracted successfully!

# %%
import os

os.listdir('dataset')
# Out:
# ['n_movies.csv']

# %%
import pandas as pd

df = pd.read_csv('dataset/n_movies.csv')

print(df.head())
print("\nColumns:")
print(df.columns)
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64
#
# Duplicate Rows:
# 0

# %%
df = df.drop_duplicates()

df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

print("Data cleaned successfully!")
# Out:
# Data cleaned successfully!

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df['certificate'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Certificates')
plt.xlabel('Certificate')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['genre'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
df['rating'].hist(bins=20)
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
top_rated = df.sort_values(by='rating', ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top_rated['title'], top_rated['rating'])
plt.xticks(rotation=90)
plt.title('Top 10 Highest Rated Netflix Shows')
plt.show()

# %%
df.to_csv('cleaned_netflix_data.csv', index=False)
